# %%
import pandas as pd

# %%
excel_file_path = r"C:\Users\16092\Downloads\Dreem_Scrum\Scrum.xlsx"  # Replace with your actual file path
df = pd.read_excel(excel_file_path)

# %%
df.head()
# Out:
#    S  Month       Date                   Request          Category  \
# 0  1   11.0 2022-11-29                      PABX      avaya System
# 1  2   11.0 2022-11-29                   Printer  Hardware Support
# 2  3   11.0 2022-11-29   Data Backup- Texture PC  Hardware Support
# 3  4   11.0 2022-11-29  R&D LAB Texture Recovery  Hardware Support
# 4  5   11.0 2022-11-29  R&D LAB Sensory Recovery  Hardware Support
#
#           Request Date Deadline Department    Division    Zone     Username  \
# 0  2022-11-28 00:00:00        -         SC  Production  DRMZ01        Helmy
# 1  2022-11-22 00:00:00        -         SC  Production  DRMZ02        Helmy
# 2  2022-11-22 00:00:00        -        R&D         R&D  DRMZ02  Mahmoud Ali
# 3  2022-11-22 00:00:00        -        R&D         Lab  DRMZ02  Mahmoud Ali
# 4  2022-11-22 00:00:00        -        R&D         Lab  DRMZ02  Mahmoud Ali
#
#     Device Name     Status                                  Details Assign to  \
# ...

# %%
# Define the request-to-category mapping
request_to_category_mapping = {
    'avaya System': 'Communication',
    'Hardware Support': 'Hardware',
    'Data Backup- Texture PC': 'Data Backup',
    'R&D LAB Texture Recovery': 'Lab Recovery',
    'R&D LAB Sensory Recovery': 'Lab Recovery',
    # Add more mappings as needed
}

# Use the map function to apply the mapping to the "Request" column and create the "Category" column
df['Category'] = df['Request'].map(request_to_category_mapping)

# Save the changes to the same Excel file
df.to_excel(excel_file_path, index=False)

print(f"Successfully updated and saved to {excel_file_path}")
# Out:
# Successfully updated and saved to C:\Users\16092\Downloads\Dreem_Scrum\Scrum.xlsx
